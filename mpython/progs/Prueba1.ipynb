# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
ar = pd.read_csv('prueba2.csv')
ar1 = pd.read_csv('prueb.csv')

# %%
ar1
# Out:
#     AceleracionX  AceleracionY  AceleracionZ Coor1 Coor2
# 0      -0.046509      0.024658      1.003906  None  None
# 1      -0.046509      0.021240      1.007324  None  None
# 2      -0.047485      0.024292      1.007813  None  None
# 3      -0.046875      0.021240      1.010132  None  None
# 4      -0.046265      0.023193      1.007324  None  None
# 5      -0.045532      0.022339      1.005371  None  None
# 6      -0.046387      0.022705      1.002197  None  None
# 7      -0.044067      0.025635      1.006348  None  None
# 8      -0.046753      0.022827      1.001465  None  None
# 9      -0.046387      0.024536      1.004761  None  None
# 10     -0.045166      0.020996      1.007813  None  None
# 11     -0.046143      0.024902      1.004883  None  None
# 12     -0.047241      0.025513      1.009888  None  None
# 13     -0.045166      0.022583      1.004761  None  None
# 14     -0.043823      0.018677      1.005981  None  None
# ...

# %%
ar1.AceleracionX.plot()

# %%
ar1.AceleracionY.plot()

# %%
print(ar1.AceleracionZ[:50].mean())
ar1.AceleracionZ[:50].plot(figsize=(14,14))
# Out:
# 1.0062622399999999

# %%
plt.plot(ar1.AceleracionX,ar1.AceleracionY)
